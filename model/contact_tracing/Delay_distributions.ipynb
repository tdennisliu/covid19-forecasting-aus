# %%
# Delay distributions

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# DELAY 1 

fig,ax = plt.subplots(figsize=(12,9))

t_p_shape = 1.0045815
t_p_scale = 1/0.3292532
t_p_offset = 0  

p = t_p_offset + np.random.gamma(t_p_scale, t_p_scale,size=10000)

p_90 = np.percentile(p,90)
print(p_90)

print("Mean: %f.2" %np.mean(p))
print("Variance: %f.2" %np.var(p))
print("90th Percentile: %f.2" %np.percentile(p,90))
ax.hist(p,bins=40, alpha=0.4)
ax.set_title("Delay 1: symptoms to swab distribution")


plt.show()
# Out:
# 16.19310482638677
# Mean: 9.193237.2
# Variance: 27.489741.2
# 90th Percentile: 16.193105.2

# %%
# DELAY 2 

# 90% of the data is < 2.4 days.

fig,ax = plt.subplots(figsize=(12,9))

t_t_shape = 7.905380
t_t_scale = 1/4.857156
t_t_offset =0

t = t_t_offset + np.random.gamma(t_t_shape, t_t_scale, size = 10000)


p_90 = np.percentile(t,90)
print(p_90)

print("Mean: %f.2" %np.mean(t))
print("Variance: %f.2" %np.var(t))
print("90th Percentile: %f.2" %np.percentile(t,90))
ax.hist(t,bins=40, alpha=0.4)
ax.set_title("Delay 2: test TAT distribution")

plt.show()
# Out:
# 2.396354747726754
# Mean: 1.629375.2
# Variance: 0.341343.2
# 90th Percentile: 2.396355.2

# %%
# DELAY 3

# 99% of the data is < 0.7 days.

fig,ax = plt.subplots(figsize=(12,9))

t_n_shape = 0.4533819
t_n_scale = 1/1.8199947
t_n_offset = 0

n = t_n_offset + np.random.gamma(t_n_shape, t_n_scale, size = 10000)

p_99 = np.percentile(n,99)
print(p_99)

print("Mean: %f.2" %np.mean(n))
print("Variance: %f.2" %np.var(n))
print("90th Percentile: %f.2" %np.percentile(n,90))
ax.hist(n,bins=40, alpha=0.4)
ax.set_title("Delay 3: time to notification distribution")

plt.show()
# Out:
# 1.8344280493641951
# Mean: 0.251067.2
# Variance: 0.145326.2
# 90th Percentile: 0.686188.2

# %%
# CURRENT DELAY DISTRIBUTION (3/2,2)

fig,ax = plt.subplots(figsize=(12,9))

x = 1+ np.random.gamma(2, 1, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")

t_p_shape = 1
t_p_scale = 1
t_p_offset = 0.5   

t_t_shape = 1
t_t_scale = 1/2
t_t_offset =0.5

t_n_shape = 1
t_n_scale = 1/2
t_n_offset = 0

#t_p_shape = 1.0045815
#t_p_scale = 1/0.3292532
#t_p_offset = 0     

#t_t_shape = 7.905380
#t_t_scale = 1/4.857156
#t_t_offset =0

#t_n_shape = 0.4533819
#t_n_scale = 1/1.8199947
#t_n_offset = 0

p = t_p_offset + np.random.gamma(t_p_scale, t_p_scale,size=10000)

t = t_t_offset + np.random.gamma(t_t_shape, t_t_scale, size = 10000)

n = t_n_offset + np.random.gamma(t_n_shape, t_n_scale, size = 10000)

ax.hist(p+t+n, bins=40, alpha=0.4)

plt.show()
# Out:
# Mean: 2.993118.2
# Variance: 2.063859.2

# %%
# CURRENT DELAY DISTRIBUTION (3/2,2)

fig,ax = plt.subplots(figsize=(12,9))

x = 1+ np.random.gamma(2, 1, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")

#t_p_shape = 1
#t_p_scale = 1
#t_p_offset = 0.5   

#t_t_shape = 1
#t_t_scale = 1/2
#t_t_offset =0.5

#t_n_shape = 1
#t_n_scale = 1/2
#t_n_offset = 0

t_p_shape = 1.0045815
t_p_scale = 1/0.3292532
t_p_offset = 0     

t_t_shape = 7.905380
t_t_scale = 1/4.857156
t_t_offset =0

t_n_shape = 0.4533819
t_n_scale = 1/1.8199947
t_n_offset = 0

p = t_p_offset + np.random.gamma(t_p_scale, t_p_scale,size=10000)

t = t_t_offset + np.random.gamma(t_t_shape, t_t_scale, size = 10000)

n = t_n_offset + np.random.gamma(t_n_shape, t_n_scale, size = 10000)

ax.hist(p+t+n, bins=40, alpha=0.4)

plt.show()
# Out:
# Mean: 2.987993.2
# Variance: 1.987149.2

# %%
fig,ax = plt.subplots(figsize=(12,9))

x = np.random.gamma(3/1, 1, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")
plt.show()
# Out:
# Mean: 2.975535.2
# Variance: 2.993582.2

# %%
fig,ax = plt.subplots(figsize=(12,9))

x = 1 + np.random.gamma(2/0.5, 0.5, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

i=3.64
j=3.07
m=5.51
n=0.948
#Generation time distribution
fig,ax = plt.subplots(figsize=(12,9))
x = np.random.gamma(i/j, j, size = 10000)
print("Generation time: \nMean: %f.2" %np.mean(x))
print("Std: %f.2" %np.std(x))
ax.hist(x,bins=40, density=True)
ax.set_title("Generation time distribution")

#Symptom onset time distribution
fig,ax = plt.subplots(figsize=(12,9))
y =  np.random.gamma(m/n, n, size = 10000)
print("Symptom Onset: \nMean: %f.2" %np.mean(y))
print("Median: %f.2" %np.median(y))
print("Std: %f.2" %np.std(y))
ax.hist(y,bins=40)
ax.set_title("Symptom onset time distribution")


#difference 
fig,ax = plt.subplots(figsize=(12,9))

print("Difference \nMean: %f.2" %np.mean(x-y))
print("Variance: %f.2" %np.var(x-y))
ax.hist(x-y,bins=40)
ax.set_title("difference time distribution")
print("The 40 pc quantile of the TG - TS is %.2f" % np.quantile(x-y,0.4))
plt.show()
