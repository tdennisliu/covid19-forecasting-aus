# %%
# Delay distributions

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# CURRENT DELAY DISTRIBUTION (3/2,2)

fig,ax = plt.subplots(figsize=(12,9))

x = np.random.gamma(3/2, 2, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")
plt.show()
# Out:
# Mean: 2.977197.2
# Variance: 5.971377.2

# %%
fig,ax = plt.subplots(figsize=(12,9))

x = np.random.gamma(3/1, 1, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")
plt.show()
# Out:
# Mean: 2.991419.2
# Variance: 3.058220.2

# %%
fig,ax = plt.subplots(figsize=(12,9))

x = np.random.gamma(3/0.3, 0.3, size = 10000)

print("Mean: %f.2" %np.mean(x))
print("Variance: %f.2" %np.var(x))
ax.hist(x,bins=40)
ax.set_title("Time to action distribution")
plt.show()
# Out:
# Mean: 2.993273.2
# Variance: 0.869440.2
